# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Krishan\Paper_Leaks_India.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\Krishan\Paper_Leaks_India.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import os

print(os.path.exists(r"C:\Users\Krishan\Paper_Leaks_India.csv"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Krishan\Paper_Leaks_India.csv", encoding="cp1252")

# %%
df
# Out:
#    Date of Exam/Incident                                          Exam Name  \
# 0             26-08-2024  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1             04-08-2024                                  MBA 1st year Exam
# 2             06-07-2024               Foreign Medical Graduate Examination
# 3             30-06-2024                  Agriculture Development Officers
# 4             18-06-2024                                       UGC NET 2024
# ..                   ...                                                ...
# 61            01-05-2016                                  NEET Phase 1 2016
# 62            25-05-2015                                       UP CPMT 2015
# 63            03-05-2015                                         AIPMT 2015
# 64            30-03-2015  Provincial civil services preliminary examination
# 65            23-06-2014                                       UP CPMT 2014
#
# ...

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.shape

# %%
df.columns

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.describe()

# %%
df.describe(include='all')

# %%
clean_df.info()

# %%
clean_df = clean_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
clean_df.head()

# %%
clean_df["Action taken"] = clean_df["Action taken"].fillna("Unknown")

# %%
clean_df.isnull().sum()

# %%
clean_df.duplicated().sum()

# %%
clean_df.drop(columns=["Appeared Students"], inplace=True)

# %%
clean_df["Action taken"] = clean_df["Action taken"].fillna("Unknown")

# %%
clean_df.isnull().sum()

# %%
clean_df["Date of Exam/Incident"].head(15)

# %%
pd.to_datetime(clean_df["Date of Exam/Incident"])

# %%
clean_df["Date of Exam/Incident"] = pd.to_datetime(
    clean_df["Date of Exam/Incident"],
    dayfirst=True
)

# %%
clean_df.info()

# %%
clean_df["Year"] = clean_df["Date of Exam/Incident"].dt.year

# %%
clean_df["Month"] = clean_df["Date of Exam/Incident"].dt.month_name()

# %%
clean_df["Month_No"] = clean_df["Date of Exam/Incident"].dt.month

# %%
clean_df["Quarter"] = clean_df["Date of Exam/Incident"].dt.quarter

# %%
clean_df.head()

# %%
clean_df["Conducting Body"].unique()

# %%
clean_df["Conducting Body Type"].unique()

# %%
clean_df["Area(s) of Incident"].unique()

# %%
clean_df["Leak Confirmation Status"].unique()

# %%
clean_df["Action taken"].unique()

# %%
clean_df["Conducting Body"].unique()

# %%
clean_df.to_csv("Paper_Leaks_Clean.csv", index=False)

# %%
# Total incidents by year
clean_df["Year"].value_counts().sort_index()

# %%
# Top Exam Names
clean_df["Exam Name"].value_counts()

# %%
# Top Conducting Bodies
clean_df["Conducting Body"].value_counts()

# %%
# State-wise incidents
clean_df["Area(s) of Incident"].value_counts()

# %%
# Leak confirmation status
clean_df["Leak Confirmation Status"].value_counts()

# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\Krishan\Paper_Leaks_Clean.csv",
    encoding="cp1252"
)

# %%
df
# Out:
#    Date of Exam/Incident                                          Exam Name  \
# 0             2024-08-26  B.Ed. 4th Sem Exam : Creating an Inclusive School
# 1             2024-08-04                                  MBA 1st year Exam
# 2             2024-07-06               Foreign Medical Graduate Examination
# 3             2024-06-30                 Agriculture Development OfficersÂ
# 4             2024-06-18                                       UGC NET 2024
# ..                   ...                                                ...
# 61            2016-05-01                                  NEET Phase 1 2016
# 62            2015-05-25                                       UP CPMT 2015
# 63            2015-05-03                                         AIPMT 2015
# 64            2015-03-30  Provincial civil services preliminary examination
# 65            2014-06-23                                       UP CPMT 2014
#
# ...

# %%
clean_df = df.copy()

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
# Total incidents by year
clean_df["Year"].value_counts().sort_index()
# Out:
# Year
# 2014     1
# 2015     3
# 2016     2
# 2017     3
# 2018     5
# 2019     3
# 2020     2
# 2021     8
# 2022    11
# 2023    15
# 2024    13
# Name: count, dtype: int64

# %%
# Top Exam Names
clean_df["Exam Name"].value_counts()
# Out:
# Exam Name
# High School Mathematics Exam                         3
# Constable Exam                                       2
# B.Ed. 4th Sem Exam : Creating an Inclusive School    1
# MBA 1st year Exam                                    1
# Foreign Medical Graduate Examination                 1
#                                                     ..
# NEET Phase 1 2016                                    1
# UP CPMT 2015                                         1
# AIPMT 2015                                           1
# Provincial civil services preliminary examination    1
# UP CPMT 2014                                         1
# Name: count, Length: 63, dtype: int64

# %%
# Top Conducting Bodies
clean_df["Conducting Body"].value_counts()
# Out:
# Conducting Body
# Uttar Pradesh Public Service Comission                                 3
# Maharashtra State Board of Secondary and Higher Secondary Education    3
# CBSE                                                                   3
# National Testing Agency                                                2
# Bihar Public service Comission                                         2
# Assam Board of Secondary Education                                     2
# West Bengal Board of Primary Education                                 2
# Telangana State Public Service Commission                              2
# Bihar School Examination Board                                         2
# Railway Recruitment Board                                              2
# Tamil Nadu Teachers Education University                               1
# Pondicherry University                                                 1
# National Board of Examinations in Medical Sciences (NBEMS)             1
# ...

# %%
# State-wise incidents
clean_df["Area(s) of Incident"].value_counts()
# Out:
# Area(s) of Incident
# Uttar Pradesh        11
# All India             7
# Maharasthra           6
# Bihar                 5
# Kerala                3
# Madhya Pradesh        3
# Gujrat                3
# Telangana             3
# Rajasthan             3
# Punjab                2
# Tripura               2
# Assam                 2
# West Bengal           2
# Odisha                2
# Himachal Pradesh      2
# Delhi                 2
# Tamilnadu             1
# Pondicherry           1
# Jharkhand             1
# Arunachal Pradesh     1
# Jammu                 1
# Uttarakhand           1
# Karnataka             1
# Haryana               1
# Name: count, dtype: int64

# %%
# Leak confirmation status
clean_df["Leak Confirmation Status"].value_counts()
# Out:
# Leak Confirmation Status
# confirmed    48
# accused      18
# Name: count, dtype: int64

# %%
clean_df["Exam Name"].value_counts().head(10)
# Out:
# Exam Name
# High School Mathematics Exam                         3
# Constable Exam                                       2
# B.Ed. 4th Sem Exam : Creating an Inclusive School    1
# MBA 1st year Exam                                    1
# Foreign Medical Graduate Examination                 1
# Agriculture Development OfficersÂ                    1
# UGC NET 2024                                         1
# ADC Recruitment Exam                                 1
# MBA Semster Exam                                     1
# VIT Engineering Exam                                 1
# Name: count, dtype: int64
